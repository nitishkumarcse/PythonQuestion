# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonQuestion/blob/main/Que9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inv = {}

def add(item, qty):
    inv[item] = qty

def delete(item):
    inv.pop(item, None)

add("Pen",10)
delete("Pen")
print(inv)
